# %%
import pandas as pd

df = pd.read_csv('.\\DataCSV\\steamspy_insights.csv', sep=',',on_bad_lines='warn')

df_filtrado=df[df["genres"]!=r"\N"]
df_filtrado[["app_id","developer","publisher","languages","genres"]]
# Out:
# C:\Users\P. Henrique\AppData\Local\Temp\ipykernel_1056\3046277561.py:3: ParserWarning: Skipping line 7794: expected 14 fields, saw 15
# Skipping line 18736: expected 14 fields, saw 15
# Skipping line 27289: expected 14 fields, saw 15
# Skipping line 45282: expected 14 fields, saw 15
# Skipping line 45678: expected 14 fields, saw 18
#
#   df = pd.read_csv('.\\DataCSV\\steamspy_insights.csv', sep=',',on_bad_lines='warn')
# C:\Users\P. Henrique\AppData\Local\Temp\ipykernel_1056\3046277561.py:3: ParserWarning: Skipping line 65747: expected 14 fields, saw 15
# Skipping line 84069: expected 14 fields, saw 15
#
#   df = pd.read_csv('.\\DataCSV\\steamspy_insights.csv', sep=',',on_bad_lines='warn')
# C:\Users\P. Henrique\AppData\Local\Temp\ipykernel_1056\3046277561.py:3: ParserWarning: Skipping line 131581: expected 14 fields, saw 16
#
#   df = pd.read_csv('.\\DataCSV\\steamspy_insights.csv', sep=',',on_bad_lines='warn')
#          app_id          developer        publisher  \
# ...

# %%
df = pd.read_csv('.\\DataCSV\\steamspy_insights.csv', sep=',', skiprows=18735, nrows=1)

df
# Out:
#    683220 Nikita \Ghost_RUS\"  "Underanger TheGachiWarrior  Ghost_RUS Games"  \
# 0  683230     White Dog Games                  SA Industry       0 .. 20,000
#
#    0 .. 20,000  0  0.1  0.2  0.3  0.4   99  99.1      0.5  \
# 0            0  0    0    0    0  899  899     0  English
#
#            English, Russian  Casual, Indie, Simulation
# 0  Action, Adventure, Indie                        NaN

# %%
df = pd.read_csv('.\\DataCSV\\tags.csv', sep=',')

df
# Out:
#           app_id             tag
# 0             10           1980s
# 1             10          1990's
# 2             10          Action
# 3             10        Assassin
# 4             10         Classic
# ...          ...             ...
# 1744627  3298710          Puzzle
# 1744628  3298710        Relaxing
# 1744629  3298710  Sexual Content
# 1744630  3298710    Singleplayer
# 1744631  3298710         Western
#
# [1744632 rows x 2 columns]

# %%
df = pd.read_csv('.\\DataCSV\\reviews.csv', sep=',',on_bad_lines='warn')

condicao_total = df['total'] != 0

df_filtrado = df[condicao_total]

df_filtrado[["app_id","review_score","review_score_description","positive","negative","total","metacritic_score","reviews","recommendations"]]
# Out:
# C:\Users\P. Henrique\AppData\Local\Temp\ipykernel_1056\3981716408.py:1: ParserWarning: Skipping line 50: expected 13 fields, saw 14
# Skipping line 180: expected 13 fields, saw 17
# Skipping line 731: expected 13 fields, saw 17
# Skipping line 866: expected 13 fields, saw 16
# Skipping line 867: expected 13 fields, saw 20
# Skipping line 878: expected 13 fields, saw 18
# Skipping line 923: expected 13 fields, saw 20
# Skipping line 1062: expected 13 fields, saw 24
# Skipping line 1731: expected 13 fields, saw 16
# Skipping line 1732: expected 13 fields, saw 17
# Skipping line 1733: expected 13 fields, saw 15
# Skipping line 1835: expected 13 fields, saw 16
# Skipping line 1955: expected 13 fields, saw 14
# Skipping line 2311: expected 13 fields, saw 19
# Skipping line 16858: expected 13 fields, saw 18
#
#   df = pd.read_csv('.\\DataCSV\\reviews.csv', sep=',',on_bad_lines='warn')
# ...
